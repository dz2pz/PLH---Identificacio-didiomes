# %% [markdown]
# # Pràctica 1: Identificació d'idiomes
#
# Jaume Majó i David Vàzquez

# %% [markdown]
# L'objectiu d'aquesta pràctica és implementar un identificador d'idiomes (basat en trigrames de caràcters) de les principals llengües europees: anglès, castellà, neerlandès, alemany, italià i francès. Per fer-ho, ens basarem amb el corpus wortschatz leipzig que conté textos de forma i mida similar en els diferents idiomes esmentats.

# %% [markdown]
# ## 1. Importem les llibreries
# En primer lloc importem les llibreries necessàries per a la implementeció de l'identificador d'idiomes.

# %%
import nltk
import re
import os
from math import log, exp
from nltk.collocations import BigramCollocationFinder, TrigramCollocationFinder, QuadgramCollocationFinder
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.base import BaseEstimator
from sklearn.metrics import make_scorer, accuracy_score
from sklearn.model_selection import GridSearchCV, StratifiedKFold
import pandas as pd

# %% [markdown]
# ## 2. Preprocessing
# A continuació, creem una funció `preprocessing(file_path)` que donat un `filepath` retorna el text preprocessat d'aquest fitxer. El preprocessament consta dels seguents passos:
# - Eliminar els símbols que es troben entre números ja que si no, en llengües com l'alemany, quedaven punts aïllats.
# - Eliminar els números.
# - Substituir espais múltiples i tabulacions per un únic espai.
# - Convertir tot el text a minúscula.
# - Concatenar totes les frases amb separació de 2 espais. D'aquesta manera, com que utilitzarem trigrames, ens asegurem que no hi haurà un trigrama amb parts de dues frases diferents.

# %%
def preprocessing(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        raw_text = file.read()
    cleaned_text = re.sub(r'(\d)[.:](\d)', r'\1\2', raw_text) # Eliminar simbols en mig dels números
    cleaned_text = re.sub(r'\d+', '', cleaned_text)  # Eliminar els números
    cleaned_text = re.sub(r'[ \t]+', ' ', cleaned_text) # Canviar (1 o més)espais i tabulacions per 1 espai
    cleaned_text = cleaned_text.lower()  # Canviar mayúscules a minúscules
    cleaned_text = cleaned_text.replace("\n", "  ") # Canviar salts de linia per espais dobles
    cleaned_text = re.sub(r' {2,}', '  ', cleaned_text) # Canviar (2 o més)espais per 2 espais
    cleaned_text = '  ' + cleaned_text.strip() + '  ' # Posar espais dobles al principi i al final després d'eliminar els espais qu hi hagin amb strip
    return cleaned_text

# %% [markdown]
# ## 3. Càlcul de probabilitats
# Definim les funcions auxiliars per calcular el valor de les probabilitats de cada idioma. En aquesta pràctica implementarem les següents 3 tècniques d'smoothing  `absolute_discounting`, `linear_discounting` i `lidstone`.
# Més endavant entrarem en detall en què consisteixen

# %%
def absolute_discounting(trad_idioma, res, N, B, delta): # Absolute discounting smoothing method
    N_0 = B - len(set(trad_idioma) & set(res))
    tot = 0
    for k, v in res.items():
        if k in trad_idioma:
            tot += v*log((trad_idioma[k] - delta)/N) if trad_idioma[k] - delta != 0 else 0
        else:
            tot += v*log(((B - N_0)*(delta / N_0))/N) if (B - N_0)*delta != 0 else 0
    return tot

def linear_discounting(trad_idioma, res, N, B, alpha): # Linear discounting smoothing method
    N_0 = B - len(set(trad_idioma) & set(res))
    tot = 0
    for k, v in res.items():
        if k in trad_idioma:
            tot += v*log((1 - alpha)*trad_idioma[k]/N) if (1 - alpha)*trad_idioma[k] != 0 else 0
        else:
            tot += v*log(alpha/N_0) if alpha != 0 else 0
    return tot

def lidstone(trad_idioma, res, N, B, lambd): # Lidstone smoothing method
    tot = 0
    for k, v in res.items():
        tot += v*log((trad_idioma.get(k, 0) + lambd)/(N + lambd*B)) if trad_idioma.get(k, 0) + lambd != 0 else 0
    return tot

# %% [markdown]
# ## 4. Model identificador d'idiomes
#
# Definim la classe `IdentificadorIdiomas` amb la que entrenarem el model per detectar l'idioma.
#
# Amb el mètode `fit` podem entrenar el model per emmagatzemar els trigrams dels corpus amb la seva etiqueta d'idioma.
# Amb el mètode `predict` calculem les probabilitats per a cada idioma, segons el mètode de smoothing escollit i retornem l'idioma més probable.
#
# Hem optat per aquesta implementació ja que pot ser modificada fàcilment per implementar noves tècniques d'smoothing (incloent els paràmetres), diferents càlculs de B, etc.

# %%
class IdentificadorIdiomas(BaseEstimator):

    def __init__(self, method="lidstone", B_compute="unified", lambd=0.5):
        self.method = method
        self.B_compute = B_compute
        self.lambd = lambd
        self.trigram = {}
        self.B = {}
        self.N = {}
        self.labels = []

    def prob_idioma(self, res, trad, method, lambd):
        idiomas = dict()
        if method == "lidstone":
            for k, v in trad.items():
                idiomas[k] = lidstone(v, res, self.N[k], self.B[k], lambd)
        elif method == "linear_discounting":
            for k, v in trad.items():
                idiomas[k] = linear_discounting(v, res, self.N[k], self.B[k], lambd)
        elif method == "absolute_discounting":
            for k, v in trad.items():
                idiomas[k] = absolute_discounting(v, res, self.N[k], self.B[k], lambd)
        return idiomas

    def fit(self, X, y):
        for idx, text in enumerate(X):
            finder = TrigramCollocationFinder.from_words(text)
            self.trigram.setdefault(y[idx], {})
            for k, v in finder.ngram_fd.items():
                self.trigram[y[idx]][k] = self.trigram[y[idx]].get(k, 0) + v
            self.B[y[idx]] = len(self.trigram.get(y[idx], []))
            self.N[y[idx]] = self.N.get(y[idx], 0) + sum(finder.ngram_fd.values())
        if self.B_compute == "unified":
            unique_keys = set()
            for k in self.trigram:
                unique_keys = unique_keys | set(self.trigram[k])
            for k in self.B:
                self.B[k] = len(unique_keys)
        return self

    def predict(self, X, method = None, lambd = None):
        # Pots canviar el metode per calcular les probabilitats
        method = method if method is not None else self.method
        lambd = lambd if lambd is not None else self.lambd
        traductor = dict()
        for k, v in self.trigram.items():
            traductor[k] = self.trigram[k].copy()
            traductor[k] = {key:traductor[k][key] for key in traductor[k] if traductor[k][key] >= 5}
        y_pred = []
        for text in X:
            finder = TrigramCollocationFinder.from_words(text)
            idiomes_pred = self.prob_idioma(finder.ngram_fd, traductor, method, lambd)
            idioma_pred = max(idiomes_pred, key=idiomes_pred.get)
            y_pred.append(idioma_pred)
        self.labels = [k for k in self.trigram]
        return y_pred
    
    def get_params(self, deep=True):
        return {
            "method": self.method,
            "B_compute": self.B_compute,
            "lambd": self.lambd
        }

    def set_params(self, **params):
        for key, value in params.items():
            setattr(self, key, value)
        return self

# %% [markdown]
# ## 5. Corpus de training i test
# Per cadascun dels idiomes, fem el preprocessament dels documents del conjunt de training. Per poder particionar els corpus de training pel crossvalidation, dividim els textos en frases.
# Guardem els textos a `X_training` i les seves etiquetes en `y_training`.

# %%
directory_path = 'langId'
traductor = dict()
X_training = []
y_training = []

for filename in os.listdir(directory_path):
    file_path = os.path.join(directory_path, filename)

    if os.path.isfile(file_path) and filename.endswith('trn.txt'):
        print(f"Trobat fitxer: {filename}")

        text = preprocessing(file_path) 
        text = text.split('  ') # Separem per doble espais
        text.pop(0) # El primer es un espai, no es una frase
        text.pop() # L'ultim es un espai, no es una frase
        text = [f"  {item}  " for item in text] # Afegim espais (que hem tret al separar amb split) al principi i al final de cada frase

        X_training.extend(text)
        y_training.extend([filename[:3]]*len(text))
# Out:
# Trobat fitxer: deu_trn.txt
# Trobat fitxer: eng_trn.txt
# Trobat fitxer: fra_trn.txt
# Trobat fitxer: ita_trn.txt
# Trobat fitxer: nld_trn.txt
# Trobat fitxer: spa_trn.txt

# %% [markdown]
# De la mateixa manera, per cadascun dels idiomes, fem el preprocessament dels documents del conjunt de test.
# Guardem els textos a `X_test` i les seves etiquetes en `y_test`.

# %%
directory_path = 'langId'
test_results = dict()
X_test = []
y_test = []

for filename in os.listdir(directory_path):
    file_path = os.path.join(directory_path, filename)

    if os.path.isfile(file_path) and filename.endswith('tst.txt'):
        print(f"Trobat fitxer: {filename}")

        text = preprocessing(file_path)
        text = text.split('  ') # Separem per doble espais
        text.pop(0) # El primer es un espai, no es una frase
        text.pop() # L'ultim es un espai, no es una frase
        text = [f"  {item}  " for item in text] # Afegim espais (que hem tret al separar amb split) al principi i al final de cada frase

        X_test.extend(text)

        y_test.extend([filename[:3]]*len(text))
# Out:
# Trobat fitxer: deu_tst.txt
# Trobat fitxer: eng_tst.txt
# Trobat fitxer: fra_tst.txt
# Trobat fitxer: ita_tst.txt
# Trobat fitxer: nld_tst.txt
# Trobat fitxer: spa_tst.txt

# %% [markdown]
# ## 6. Entrenament, predicció i visualització de resultats
# A continuació fem un exemple d'ús de la classe per a l'entrenament, predicció i visualització de resultats
# - Entrenem el model amb els corpus de training i fem una predicció amb el mètode de lidstone (per exemple lambda = 0.2, més endavant ja buscarem la configuració óptima).
# - Grafiquem la matriu de confusió del nostre identificador d'idioma.
# - Obtenim una precisió del 99,88% la qual cosa ens indica que el model funciona correctament ja que, com ja hem vist, els corpus de training i de test utilitzen les mateixes frases i, per tant, la precisió es tant elevada.

# %%
II = IdentificadorIdiomas(method = "absolute_discounting", B_compute="not_unified", lambd = 0.2) # Posem un mètode per que sigui el predeterminat si no afegim mètode per predict
II.fit(X_training, y_training)
y_pred = II.predict(X_test, method="lidstone", lambd = 0.5)

accuracy = accuracy_score(y_test, y_pred)

print(f"Accuracy: {accuracy}")

cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=II.labels, yticklabels=II.labels)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Accuracy: 0.9988328859396102

# %% [markdown]
# ## 7. Crossvalidation per trobar els millors paràmetres
# Ara passem a optimitzar els diferents paràmetres dels mètodes d'smoothing per tal de trobar el millor identificador d'idioma en cadascun dels casos.
# Per fer-ho usarem `GridSearch` amb els diferents paràmetres de lambda i provant tant amb `unified` i `not_unified` per les diferents definicions de B.
#
# ### Lidstone
# La idea principal de Lidstone és asumir que cadascun dels trigrams han tingut més presència (lambda) de la que realment han tingut.
# D'aquesta manera aconseguim que no hi hagi una probabilitat igual a zero i, per tant, tot el productori de probabilitats quedi a zero.
#
# $$ P(w_1 w_2 w_3) = \frac{C(w_1 w_2 w_3) + \lambda}{N + \lambda B} $$
#
# Necessitem $C(w_1 w_2 w_3)$ que es el nombre de vegades que surt cert trigram als corpus de training. També fa falta $N$ que es el nombre de trigrams dels corpus de training.
# Però $B$ es el nombre de trigrams únics vistos que podem considerar els trigrams diferents per cada llengüatge o unificar els llengüatges. I $\lambda$ es una constant que evita les probabilitats de zero per a trigrams desconeguts, i volem trobar el seu millor valor.
# Per saber si pel mètode de smoothing lidstone es millor utilitzar una $B$ diferent per cada llengüatge o si es millor unificar-les i, a més, per saber quina $\lambda$ es millor, farem un crossvalidation per trobar el millor model.
# En el cas de $B$ creiem que te més sentit que els trigrams de tots els idiomes siguin unificats, comptant-los tots ja que pots veure paraules d'un idioma en un altre i viceversa. Encara i així, probarem ambdues opcions per veure quina dona millors resultats.

# %%
param_grid = {
    "lambd": [0, 0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 1],
    "B_compute": ["unified", "not_unified"]
}

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

gs = GridSearchCV(
    estimator=IdentificadorIdiomas(method="lidstone"),
    param_grid=param_grid,
    scoring='accuracy',
    cv=cv,
    n_jobs=-1
)

gs.fit(X_training, y_training)

y_pred = gs.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)

print(f"Accuracy: {accuracy}")

cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=II.labels, yticklabels=II.labels)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

results_df = pd.DataFrame(gs.cv_results_)
results_df = results_df.sort_values(by=["rank_test_score"])
results_df = results_df.set_index(results_df["params"].apply(lambda x: "_".join(str(val) for val in x.values()))).rename_axis("model")
results_df[["params", "rank_test_score", "mean_test_score", "std_test_score"]]
# Out:
# Accuracy: 0.9988495589976157
#                                                          params  \
# model
# unified_1                  {'B_compute': 'unified', 'lambd': 1}
# unified_0.5              {'B_compute': 'unified', 'lambd': 0.5}
# not_unified_1          {'B_compute': 'not_unified', 'lambd': 1}
# not_unified_0.5      {'B_compute': 'not_unified', 'lambd': 0.5}
# unified_0.1              {'B_compute': 'unified', 'lambd': 0.1}
# not_unified_0.1      {'B_compute': 'not_unified', 'lambd': 0.1}
# unified_0.05            {'B_compute': 'unified', 'lambd': 0.05}
# not_unified_0.05    {'B_compute': 'not_unified', 'lambd': 0.05}
# unified_0.01            {'B_compute': 'unified', 'lambd': 0.01}
# not_unified_0.01    {'B_compute': 'not_unified', 'lambd': 0.01}
# unified_0.005          {'B_compute': 'unified', 'lambd': 0.005}
# not_unified_0.005  {'B_compute': 'not_unified', 'lambd': 0.005}
# unified_0.001          {'B_compute': 'unified', 'lambd': 0.001}
# not_unified_0.001  {'B_compute': 'not_unified', 'lambd': 0.001}
# unified_0                  {'B_compute': 'unified', 'lambd': 0}
# not_unified_0          {'B_compute': 'not_unified', 'lambd': 0}
#
#                    rank_test_score  mean_test_score  std_test_score
# model
# unified_1                        1         0.998621        0.000080
# unified_0.5                      2         0.998616        0.000089
# not_unified_1                    3         0.998610        0.000084
# not_unified_0.5                  4         0.998610        0.000082
# unified_0.1                      5         0.998504        0.000073
# not_unified_0.1                  5         0.998504        0.000073
# unified_0.05                     7         0.998427        0.000033
# not_unified_0.05                 7         0.998427        0.000033
# unified_0.01                     9         0.998276        0.000082
# not_unified_0.01                 9         0.998276        0.000082
# unified_0.005                   11         0.998188        0.000087
# not_unified_0.005               11         0.998188        0.000087
# unified_0.001                   13         0.998021        0.000102
# not_unified_0.001               13         0.998021        0.000102
# unified_0                       15         0.624464        0.002849
# not_unified_0                   15         0.624464        0.002849

# %% [markdown]
# Podem veure que els millors paràmetres son $B$ unificada en tots els idiomes i $\lambda = 1$.
# No sembla però, tenir molta influencia el valor de la $\lambda$ més enllà de evitar probabilitats nules. (Ja que les precisions no varien significativament entre $\lambda = 0.001$ i $\lambda = 1$)

# %% [markdown]
# ### Linear discounting
# A diferència de Lidstone, la idea de linear discounting és treure una porció de probabilitat ($\alpha$) per tal de redistribuir-la entre els trigrames (o paraules, en cas de predir per paraules) no observats.
# L'objectiu d'això és el mateix que abans, evitar que la probabilitat sigui diferent de zero.
#
# $$ P(w_1 w_2 w_3) = \left\{ \begin{array}{l}  (1 - \alpha)\frac{C(w_1 w_2 w_3)}{N} \\ \alpha/N_0 \end{array} \begin{array}{l} if \ C(w_1 w_2 w_3) > 0 \\ otherwise \end{array}\right. $$
#
# A més del que hem vist a `lidstone` necessitem $N_0$ que son el nombre de possibles trigrams observats 0 vegades. Però $\alpha$ es una proporció constant que no sabem el seu millor valor.
# De nou, per saber si pel mètode de smoothing lidstone es millor utilitzar una $B$ diferent per cada llengüatge o si es millor unificar-les i, a més, per saber quina $\alpha$ (lambd en el nostre codi) es millor, farem un crossvalidation per trobar el millor model.

# %%
param_grid = {
    "lambd": [0, 0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 1],
    "B_compute": ["unified", "not_unified"]
}

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=83)

gs_ld = GridSearchCV(
    estimator=IdentificadorIdiomas(method="linear_discounting"),
    param_grid=param_grid,
    scoring='accuracy',
    cv=cv,
    n_jobs=-1
)

gs_ld.fit(X_training, y_training)

y_pred = gs_ld.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)

print(f"Accuracy: {accuracy}")

cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=II.labels, yticklabels=II.labels)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

results_df = pd.DataFrame(gs_ld.cv_results_)
results_df = results_df.sort_values(by=["rank_test_score"])
results_df = results_df.set_index(results_df["params"].apply(lambda x: "_".join(str(val) for val in x.values()))).rename_axis("model")
results_df[["params", "rank_test_score", "mean_test_score", "std_test_score"]]
# Out:
# Accuracy: 0.9988495589976157
#                                                          params  \
# model
# unified_0.01            {'B_compute': 'unified', 'lambd': 0.01}
# not_unified_0.005  {'B_compute': 'not_unified', 'lambd': 0.005}
# unified_0.05            {'B_compute': 'unified', 'lambd': 0.05}
# unified_0.005          {'B_compute': 'unified', 'lambd': 0.005}
# not_unified_0.01    {'B_compute': 'not_unified', 'lambd': 0.01}
# not_unified_0.001  {'B_compute': 'not_unified', 'lambd': 0.001}
# unified_0.1              {'B_compute': 'unified', 'lambd': 0.1}
# unified_0.001          {'B_compute': 'unified', 'lambd': 0.001}
# not_unified_0.05    {'B_compute': 'not_unified', 'lambd': 0.05}
# not_unified_0.1      {'B_compute': 'not_unified', 'lambd': 0.1}
# unified_0.5              {'B_compute': 'unified', 'lambd': 0.5}
# not_unified_0.5      {'B_compute': 'not_unified', 'lambd': 0.5}
# not_unified_1          {'B_compute': 'not_unified', 'lambd': 1}
# unified_1                  {'B_compute': 'unified', 'lambd': 1}
# unified_0                  {'B_compute': 'unified', 'lambd': 0}
# not_unified_0          {'B_compute': 'not_unified', 'lambd': 0}
#
#                    rank_test_score  mean_test_score  std_test_score
# model
# unified_0.01                     1         0.998610        0.000177
# not_unified_0.005                2         0.998604        0.000198
# unified_0.05                     3         0.998604        0.000216
# unified_0.005                    4         0.998604        0.000223
# not_unified_0.01                 5         0.998588        0.000184
# not_unified_0.001                6         0.998560        0.000203
# unified_0.1                      7         0.998543        0.000218
# unified_0.001                    8         0.998516        0.000226
# not_unified_0.05                 9         0.998510        0.000187
# not_unified_0.1                 10         0.998404        0.000205
# unified_0.5                     11         0.997848        0.000258
# not_unified_0.5                 12         0.996814        0.000239
# not_unified_1                   13         0.912889        0.001579
# unified_1                       14         0.905094        0.001757
# unified_0                       15         0.625648        0.003695
# not_unified_0                   15         0.625648        0.003695

# %% [markdown]
# Podem veure que els millors paràmetres son $B$ unificada en tots els idiomes i $\alpha = 0.01$.
# Veiem que per $\alpha = 1$ hi ha una caiguda enorme de precisió respecte els altres valors (excepte 0 que seria equivalent a no aplicar smoothing), això es deu que amb aquest valor de $\alpha$ estariem predint tenint en compte només els trigrams desconeguts.
# Això, clarament, no té sentit, es molt més raonable que els trigrams desconeguts tinguin poca importància, com $\alpha = 0.01$ que es el valor donat.

# %% [markdown]
# ### Absolute discounting
# La diferència principal d'aquest mètode és que, a diferència de Linear Discounting, descompte un valor constant a cadascuna de les probabilitats dels trigrames observats i fa que els trigrams no observats retornin una probabilitat més baixa.
# De la mateixa manera que abans, redistribueix el restant entre els trigrames no observats.
#
# $$ P(w_1 w_2 w_3) = \left\{ \begin{array}{l}  (1 - \delta)\frac{C(w_1 w_2 w_3) - \delta}{N} \\ \frac{(B - N_0) \delta / N_0}{N} \end{array} \begin{array}{l} if \ C(w_1 w_2 w_3) > 0 \\ otherwise \end{array}\right. $$
#
# A més del que hem vist a `lidstone` i `linear_discounting` necessitem $\delta$ de la cual que no sabem el seu millor valor.
# Per tant, per saber si pel mètode de smoothing lidstone es millor utilitzar una $B$ diferent per cada llengüatge o si es millor unificar-les i, a més, per saber quina $\delta$ (lambd en el nostre codi) es millor, farem un crossvalidation per trobar el millor model.

# %%
param_grid = {
    "lambd": [0, 0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 1],
    "B_compute": ["unified", "not_unified"]
}

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=65)

gs_ad = GridSearchCV(
    estimator=IdentificadorIdiomas(method="absolute_discounting"),
    param_grid=param_grid,
    scoring='accuracy',
    cv=cv,
    n_jobs=-1
)

gs_ad.fit(X_training, y_training)

y_pred = gs_ad.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)

print(f"Accuracy: {accuracy}")

cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=II.labels, yticklabels=II.labels)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

results_df = pd.DataFrame(gs_ad.cv_results_)
results_df = results_df.sort_values(by=["rank_test_score"])
results_df = results_df.set_index(results_df["params"].apply(lambda x: "_".join(str(val) for val in x.values()))).rename_axis("model")
results_df[["params", "rank_test_score", "mean_test_score", "std_test_score"]]
# Out:
# Accuracy: 0.9983326941994431
#                                                          params  \
# model
# not_unified_1          {'B_compute': 'not_unified', 'lambd': 1}
# not_unified_0.5      {'B_compute': 'not_unified', 'lambd': 0.5}
# unified_1                  {'B_compute': 'unified', 'lambd': 1}
# unified_0.5              {'B_compute': 'unified', 'lambd': 0.5}
# not_unified_0.1      {'B_compute': 'not_unified', 'lambd': 0.1}
# unified_0.1              {'B_compute': 'unified', 'lambd': 0.1}
# not_unified_0.05    {'B_compute': 'not_unified', 'lambd': 0.05}
# unified_0.05            {'B_compute': 'unified', 'lambd': 0.05}
# not_unified_0.01    {'B_compute': 'not_unified', 'lambd': 0.01}
# not_unified_0.005  {'B_compute': 'not_unified', 'lambd': 0.005}
# unified_0.01            {'B_compute': 'unified', 'lambd': 0.01}
# unified_0.005          {'B_compute': 'unified', 'lambd': 0.005}
# not_unified_0.001  {'B_compute': 'not_unified', 'lambd': 0.001}
# unified_0.001          {'B_compute': 'unified', 'lambd': 0.001}
# unified_0                  {'B_compute': 'unified', 'lambd': 0}
# not_unified_0          {'B_compute': 'not_unified', 'lambd': 0}
#
#                    rank_test_score  mean_test_score  std_test_score
# model
# not_unified_1                    1         0.998087        0.000211
# not_unified_0.5                  2         0.997998        0.000217
# unified_1                        3         0.997998        0.000224
# unified_0.5                      4         0.997904        0.000191
# not_unified_0.1                  5         0.997826        0.000211
# unified_0.1                      6         0.997787        0.000188
# not_unified_0.05                 6         0.997787        0.000171
# unified_0.05                     8         0.997693        0.000168
# not_unified_0.01                 9         0.997576        0.000188
# not_unified_0.005               10         0.997476        0.000217
# unified_0.01                    11         0.997431        0.000268
# unified_0.005                   12         0.997348        0.000273
# not_unified_0.001               13         0.997237        0.000266
# unified_0.001                   14         0.997137        0.000329
# unified_0                       15         0.623980        0.001454
# not_unified_0                   15         0.623980        0.001454

# %% [markdown]
# Podem veure que els millors paràmetres son $B$ unificada en tots els idiomes i $\delta = 1$.
# Veiem que el valor amb la millor $\delta$ és més gran que el valor amb la millor $\alpha$ linear discounting, això te sentit ja que la probabilitat dels trigrams no observats es més baixa ja que $N > B$.
# Això fa que $\delta$ hagi de compensar per absolute discounting.
# Encara més curiós es que el valor $\delta = 1$ fa que no li doni importància als trigrams coneguts, el qual només funciona ja que hem posat que $log(0) = 0$ però, encara i així no hauria de passar que aquest valor doni millor precisió que valors més petits.
